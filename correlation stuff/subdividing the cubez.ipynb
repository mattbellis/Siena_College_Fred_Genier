# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import time
# %matplotlib notebook
sn.set_style("ticks",sn.axes_style({'axes.grid': True}))

# %%
random = np.loadtxt('Gravitationally_Rigid_Intergalactic_Dimensions_10k_random.dat')
data = np.loadtxt('Gravitationally_Rigid_Intergalactic_Dimensions_10k_data.dat')

# %%
dt = data.transpose()
rt = random.transpose()

# %%
### Data ###

div1=[]
div2=[]
div3=[]
div4=[]
div5=[]
div6=[]
div7=[]
div8=[]

mx = np.median((min(dt[0]),max(dt[0])))
my = np.median((min(dt[1]),max(dt[1])))
mz = np.median((min(dt[2]),max(dt[2])))


for i in data:
    
    if   i[0]<=mx and i[1]<=my and i[2]<=mz:
        div1.append(i)
    elif i[0]<=mx and i[1]<=my and i[2]> mz:
        div2.append(i)
    elif i[0]<=mx and i[1]> my and i[2]<=mz:
        div3.append(i) 
    elif i[0]> mx and i[1]<=my and i[2]<=mz:
        div4.append(i)
    elif i[0]> mx and i[1]> my and i[2]<=mz:
        div5.append(i)
    elif i[0]> mx and i[1]<=my and i[2]> mz:
        div6.append(i)
    elif i[0]<=mx and i[1]> my and i[2]> mz:
        div7.append(i)
    elif i[0]> mx and i[1]> my and i[2]> mz:
        div8.append(i)
        
print(len(div1)+len(div2)+len(div3)+len(div4)+len(div5)+len(div6)+len(div7)+len(div8))
# Out:
# 10000

# %%
### Random ###

rdiv1=[]
rdiv2=[]
rdiv3=[]
rdiv4=[]
rdiv5=[]
rdiv6=[]
rdiv7=[]
rdiv8=[]

mx = np.median((min(rt[0]),max(rt[0])))
my = np.median((min(rt[1]),max(rt[1])))
mz = np.median((min(rt[2]),max(rt[2])))


for i in random:
    
    if   i[0]<=mx and i[1]<=my and i[2]<=mz:
        rdiv1.append(i)
    elif i[0]<=mx and i[1]<=my and i[2]> mz:
        rdiv2.append(i)
    elif i[0]<=mx and i[1]> my and i[2]<=mz:
        rdiv3.append(i) 
    elif i[0]> mx and i[1]<=my and i[2]<=mz:
        rdiv4.append(i)
    elif i[0]> mx and i[1]> my and i[2]<=mz:
        rdiv5.append(i)
    elif i[0]> mx and i[1]<=my and i[2]> mz:
        rdiv6.append(i)
    elif i[0]<=mx and i[1]> my and i[2]> mz:
        rdiv7.append(i)
    elif i[0]> mx and i[1]> my and i[2]> mz:
        rdiv8.append(i)
        
print(len(rdiv1)+len(rdiv2)+len(rdiv3)+len(rdiv4)+len(rdiv5)+len(rdiv6)+len(rdiv7)+len(rdiv8))
# Out:
# 10000

# %%
### Plot data ###

from mpl_toolkits.mplot3d import Axes3D
#plt.figure()
#ax = plt.axes(projection='3d')

#ax.scatter(np.array(div1).transpose()[0],np.array(div1).transpose()[1],np.array(div1).transpose()[2],s=30)
#ax.scatter(np.array(div2).transpose()[0],np.array(div2).transpose()[1],np.array(div2).transpose()[2],s=30)
#ax.scatter(np.array(div3).transpose()[0],np.array(div3).transpose()[1],np.array(div3).transpose()[2],s=30)
#ax.scatter(np.array(div4).transpose()[0],np.array(div4).transpose()[1],np.array(div4).transpose()[2],s=30)
#ax.scatter(np.array(div5).transpose()[0],np.array(div5).transpose()[1],np.array(div5).transpose()[2],s=30)
#ax.scatter(np.array(div6).transpose()[0],np.array(div6).transpose()[1],np.array(div6).transpose()[2],s=30)
#ax.scatter(np.array(div7).transpose()[0],np.array(div7).transpose()[1],np.array(div7).transpose()[2],s=30)
#ax.scatter(np.array(div8).transpose()[0],np.array(div8).transpose()[1],np.array(div8).transpose()[2],s=30)

### Plot random ###
plt.figure()
ax2 = plt.axes(projection='3d')

ax2.scatter(np.array(rdiv1).transpose()[0],np.array(rdiv1).transpose()[1],np.array(rdiv1).transpose()[2],s=30)
ax2.scatter(np.array(rdiv2).transpose()[0],np.array(rdiv2).transpose()[1],np.array(rdiv2).transpose()[2],s=30)
ax2.scatter(np.array(rdiv3).transpose()[0],np.array(rdiv3).transpose()[1],np.array(rdiv3).transpose()[2],s=30)
ax2.scatter(np.array(rdiv4).transpose()[0],np.array(rdiv4).transpose()[1],np.array(rdiv4).transpose()[2],s=30)
ax2.scatter(np.array(rdiv5).transpose()[0],np.array(rdiv5).transpose()[1],np.array(rdiv5).transpose()[2],s=30)
ax2.scatter(np.array(rdiv6).transpose()[0],np.array(rdiv6).transpose()[1],np.array(rdiv6).transpose()[2],s=30)
ax2.scatter(np.array(rdiv7).transpose()[0],np.array(rdiv7).transpose()[1],np.array(rdiv7).transpose()[2],s=30)
ax2.scatter(np.array(rdiv8).transpose()[0],np.array(rdiv8).transpose()[1],np.array(rdiv8).transpose()[2],s=30)

plt.title("Random Points")

# %%
def distance(a,b):
    dist = np.sqrt( (b[0]-a[0])**2 + (b[1]-a[1])**2 + (b[2]-a[2])**2 )
    return dist

ddivs=[div1,div2,div3,div4,div5,div6,div7,div8]
rdivs=[rdiv1,rdiv2,rdiv3,rdiv4,rdiv5,rdiv6,rdiv7,rdiv8]

# %%
### DD ###

dd=[]

start = time.time()

### subdiv-subdiv ###

for idiv in range(0,len(ddivs)-1):
    
    subdiv = ddivs[idiv]
    
    for jdiv in range(idiv+1,8):
    
        subdiv2 = ddivs[jdiv]
        
        for j in range(0,len(subdiv)):
        
            pos1=subdiv[j]
            pos2=np.array(subdiv2[:]).transpose()
            dist=distance(pos1,pos2)
            dd += dist.tolist()
            
### subdiv-self ###
    
for idiv in range(0,len(ddivs)):
    
    subdiv = ddivs[idiv]
    
    for i in range(0,len(subdiv)-1):
        pos1=subdiv[i]
        pos2=np.array(subdiv[i+1:]).transpose()
        dist=distance(pos1,pos2)
        dd+=dist.tolist()

step1=time.time()

print("Done (DD)! Took %.1f seconds." % (step1-start))

print ("%.2e datapoints." % (len(dd)))

plt.figure()
hist_dd=plt.hist(dd,bins=200)
sn.despine()
print(len(dd))
# Out:
# Done (DD)! Took 17.2 seconds.
# 5.00e+07 datapoints.
# <img src="data:image/png;base64,..." width="640">
# 49995000

# %%
### DR ###
dr=[]

start = time.time()

for idiv in range(0,8):
    
    subdiv1 = ddivs[idiv]
    
    for jdiv in range(0,8):
        
        #print(idiv+1,jdiv+1) #debug
    
        subdiv2 = rdivs[jdiv]
        
        for j in range(0,len(subdiv1)):
        
            pos1=subdiv1[j]
            pos2=np.array(subdiv2).transpose()
            dist=distance(pos1,pos2)
            dr += dist.tolist()
            
end = time.time()

print("Done! (DR) Took %.2f seconds"%(end-start))
print("%.2e datapoints."%(len(dr)))

plt.figure()
hist_dr=plt.hist(dr,bins=200)
sn.despine()
print(len(dr))
# Out:
# Done! (DR) Took 33.65 seconds
# 1.00e+08 datapoints.
# <img src="data:image/png;base64,..." width="640">
# 100000000

# %%
### RR ###

rr=[]

start = time.time()

### subdiv-subdiv ###

for idiv in range(0,len(rdivs)-1):
    
    subdiv = rdivs[idiv]
    
    for jdiv in range(idiv+1,8):
    
        subdiv2 = rdivs[jdiv]
        
        for j in range(0,len(subdiv)):
        
            pos1=subdiv[j]
            pos2=np.array(subdiv2[:]).transpose()
            dist=distance(pos1,pos2)
            rr += dist.tolist()
            
### subdiv-self ###
    
for idiv in range(0,len(rdivs)):
    
    subdiv = rdivs[idiv]
    
    for i in range(0,len(subdiv)-1):
        pos1=subdiv[i]
        pos2=np.array(subdiv[i+1:]).transpose()
        dist=distance(pos1,pos2)
        rr+=dist.tolist()


end = time.time()

print("Done (RR)! Took %.1f seconds." % (end-start))

print ("%.2e datapoints." % (len(rr)))

plt.figure()
hist_rr=plt.hist(rr,bins=200)
sn.despine()
print(len(rr))
# Out:
# Done (RR)! Took 17.3 seconds.
# 5.00e+07 datapoints.
# <img src="data:image/png;base64,..." width="640">
# 49995000

# %%
norm = (((1e4)**2)-1e4)/2.0
dr_norm = (1e4)**2

zeta = (hist_dd[0]/norm - 2*hist_dr[0]/dr_norm + hist_rr[0]/norm)/(hist_rr[0]/norm)

plt.figure()
#plt.plot(hist_dd[1][0:-1],zeta,'o')
plt.plot(hist_dd[1][0:-1],zeta)
# Out:
# <img src="data:image/png;base64,..." width="640">
