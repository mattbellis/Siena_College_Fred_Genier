# %%
import h5py

# %%
import numpy as np

#array = []

#for i in range(0,100000):
#    array.append(np.random.random(32))

#array = np.array(array)

# %%
#np.savetxt('100000.txt',array)

# %%
#np.save('100000.npy',array)

# %%
#np.savez('100000.npz',array)

# %%
#np.savez_compressed('100000_c.npz',array)

# %%
#np.savetxt('txtz.txt',array)

# %%
#import zipfile

#with zipfile.ZipFile('txt.zip', 'w') as myzip:
#    myzip.write('txtz.txt')

# %%
#with h5py.File('100000.hdf5','w') as hf:
#    hf.create_dataset('dset1',data=array)
import time

txtt = []
npyt = []
npzt = []
npz_ct = []
hdf5t = []

# %%
for x in range(1,6):
    num = 10**x
    Ftype = '.hdf5'
    name = "%d_c%s" % (num,Ftype)
    arr = np.random.random(size=(num,32))
    t1 = time.time()
    
    #np.savez_compressed(name,arr)
    with h5py.File(name,'w') as hf:
        hf.create_dataset('dset1',data=arr)
    
    dt = time.time() - t1
    hdf5t.append(dt)

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib notebook

x = [10,100,1000,10000,100000]

plt.plot(x,txtt,'o',markersize=10,label='txt')
plt.plot(x,npyt,'s',markersize=10,label='npy')
plt.plot(x,npzt,'^',markersize=10,label='npz')
plt.plot(x,npz_ct,'*',markersize=10,label='npzc')
plt.plot(x,hdf5t,'H',markersize=10,label='hdf5')
plt.xscale('log')
plt.yscale('log')
#plt.ylim(.0001,3)
#plt.xlim(9,150000)
# Out:
# <img src="data:image/png;base64,...">
